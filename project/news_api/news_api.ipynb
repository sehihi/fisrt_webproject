# %%
#### NAVER API

import requests
import mysql.connector
import time
from datetime import datetime

# 네이버 API 설정
NAVER_CLIENT_ID = 'c1M21TFbnPsLTH9OSif4'
NAVER_CLIENT_SECRET = 'futUGBEK8j'
NAVER_API_URL = 'https://openapi.naver.com/v1/search/news.json'

# MySQL 설정
MYSQL_HOST = 'localhost'
MYSQL_USER = 'root'
MYSQL_PASSWORD = '0000'
MYSQL_DATABASE = 'userdb'

# 특정 키워드 설정
KEYWORD = '삼성중공업'

def fetch_news_from_naver(keyword):
    # 헤더는 요청을 보낼 때 서버에 추가적인 정보를 전달하는 데 사용됩니다
    headers = {
        'X-Naver-Client-Id': NAVER_CLIENT_ID,
        'X-Naver-Client-Secret': NAVER_CLIENT_SECRET
    }
    # params는 URL에 추가될 쿼리 문자열을 포함하고 있으며, API에 전달할 검색 조건이나 옵션 등을 지정할 수 있습니다
    params = {
        'query': keyword,
        'display': 100,  # 최대 100개 뉴스 추출
        'start': 1,      # 시작 위치
        'sort': 'date'   # 날짜 기준으로 정렬
    }
    # requests.get 함수는 네이버 뉴스 API와 같은 웹 API에 요청을 보내고 응답을 받아옵니다
    response = requests.get(NAVER_API_URL, headers = headers, params = params)
    # response.raise_for_status()는 Python의 requests 라이브러리에서 사용되는 메서드로, HTTP 요청의 응답 상태 코드를 확인하고, 요청이 실패했을 경우 예외를 발생
    response.raise_for_status()
    return response.json()

def save_news_to_db(news_items):
    connection = mysql.connector.connect(
        host = MYSQL_HOST,
        user = MYSQL_USER,
        password = MYSQL_PASSWORD,
        database = MYSQL_DATABASE
    )
    cursor = connection.cursor()
    
    insert_query = """INSERT INTO news (title, description, link, pubDate) VALUES (%s, %s, %s, %s)"""
    check_query = """SELECT COUNT(*) FROM news WHERE link = %s"""


    
    # 네이버 API에서 받은 뉴스 기사 데이터베이스에 삽입
    for item in news_items:
        title = item['title'].replace('<b>', '').replace('</b>', '')  
        description = item['description'].replace('<b>', '').replace('</b>', '')
        link = item['link']
        pubDate = datetime.strptime(item['pubDate'], "%a, %d %b %Y %H:%M:%S %z")

        cursor.execute(check_query, (link,))
        count_result = cursor.fetchone()
        count = count_result[0] if count_result else 0

        if count == 0:
            document = (title, description, link, pubDate)
            cursor.execute(insert_query, document)
    
    connection.commit()
    cursor.close()
    connection.close()

def fetch_and_sort_news():
    connection = mysql.connector.connect(
        host = MYSQL_HOST,
        user = MYSQL_USER,
        password = MYSQL_PASSWORD,
        database = MYSQL_DATABASE
    )
    cursor = connection.cursor()
    
    # 뉴스 데이터를 pubDate 기준으로 정렬
    select_query = """SELECT title, description, link, pubDate FROM news ORDER BY pubDate DESC"""
    
    try:
        cursor.execute(select_query)
        news_items = cursor.fetchall()

    except mysql.connector.Error as err:
        print(f"Error: {err}")
    
    finally:
        cursor.close()
        connection.close()

    cursor.close()
    connection.close()

def main():
    try:
        while True:
            try:
                news_data = fetch_news_from_naver(KEYWORD)
                news_items = news_data.get('items', [])
                save_news_to_db(news_items)
                fetch_and_sort_news()
                print(f"{datetime.now()}: News data fetched and saved and sorted to database.")

            except Exception as e:
                print(f"Error during fetching or saving news: {e}")
            time.sleep(60)  # 1분 대기
    except KeyboardInterrupt:
        print("\nProgram terminated by user.")
    finally:
        print("Exiting program...")

if __name__ == "__main__":
    main()
# Out:
# 2024-09-12 08:57:12.980297: News data fetched and saved and sorted to database.
# 2024-09-12 08:58:13.186128: News data fetched and saved and sorted to database.
# 2024-09-12 08:59:13.379014: News data fetched and saved and sorted to database.
# 2024-09-12 09:00:13.546604: News data fetched and saved and sorted to database.
# 2024-09-12 09:01:13.754159: News data fetched and saved and sorted to database.
# 2024-09-12 09:02:13.946119: News data fetched and saved and sorted to database.
# 2024-09-12 09:03:14.159908: News data fetched and saved and sorted to database.
# 2024-09-12 09:04:14.350948: News data fetched and saved and sorted to database.
# 2024-09-12 09:05:14.463314: News data fetched and saved and sorted to database.
# 2024-09-12 09:06:14.676453: News data fetched and saved and sorted to database.
# 2024-09-12 09:07:14.867886: News data fetched and saved and sorted to database.
# 2024-09-12 09:08:15.080711: News data fetched and saved and sorted to database.
# 2024-09-12 09:09:15.295012: News data fetched and saved and sorted to database.
# 2024-09-12 09:10:15.505440: News data fetched and saved and sorted to database.
# 2024-09-12 09:11:15.715425: News data fetched and saved and sorted to database.
# 2024-09-12 09:12:15.912570: News data fetched and saved and sorted to database.
# 2024-09-12 09:13:16.105159: News data fetched and saved and sorted to database.
# 2024-09-12 09:14:16.293062: News data fetched and saved and sorted to database.
# 2024-09-12 09:15:16.511509: News data fetched and saved and sorted to database.
# 2024-09-12 09:16:16.705378: News data fetched and saved and sorted to database.
# 2024-09-12 09:17:16.907298: News data fetched and saved and sorted to database.
# 2024-09-12 09:18:17.029903: News data fetched and saved and sorted to database.
# 2024-09-12 09:19:17.231821: News data fetched and saved and sorted to database.
# 2024-09-12 09:20:17.407715: News data fetched and saved and sorted to database.
# 2024-09-12 09:21:17.630706: News data fetched and saved and sorted to database.
# 2024-09-12 09:22:17.737431: News data fetched and saved and sorted to database.
# 2024-09-12 09:23:17.941396: News data fetched and saved and sorted to database.
# 2024-09-12 09:24:18.163890: News data fetched and saved and sorted to database.
# 2024-09-12 09:25:18.377586: News data fetched and saved and sorted to database.
# 2024-09-12 09:26:18.664684: News data fetched and saved and sorted to database.
# 2024-09-12 09:27:18.776524: News data fetched and saved and sorted to database.
# 2024-09-12 09:28:18.994107: News data fetched and saved and sorted to database.
# 2024-09-12 09:29:19.114405: News data fetched and saved and sorted to database.
# 2024-09-12 09:30:19.305392: News data fetched and saved and sorted to database.
# 2024-09-12 09:31:19.501178: News data fetched and saved and sorted to database.
# 2024-09-12 09:32:19.706357: News data fetched and saved and sorted to database.
# 2024-09-12 09:33:19.924651: News data fetched and saved and sorted to database.
# 2024-09-12 09:34:20.143739: News data fetched and saved and sorted to database.
# 2024-09-12 09:35:20.341139: News data fetched and saved and sorted to database.
# 2024-09-12 09:36:20.526471: News data fetched and saved and sorted to database.
# 2024-09-12 09:37:20.708448: News data fetched and saved and sorted to database.
# 2024-09-12 09:38:20.816884: News data fetched and saved and sorted to database.
# 2024-09-12 09:39:21.020331: News data fetched and saved and sorted to database.
# 2024-09-12 09:40:21.197160: News data fetched and saved and sorted to database.
# 2024-09-12 09:41:21.397970: News data fetched and saved and sorted to database.
# 2024-09-12 09:42:21.605023: News data fetched and saved and sorted to database.
# 2024-09-12 09:43:21.726680: News data fetched and saved and sorted to database.
# 2024-09-12 09:44:21.934090: News data fetched and saved and sorted to database.
# 2024-09-12 09:45:22.135274: News data fetched and saved and sorted to database.
# 2024-09-12 09:46:22.249092: News data fetched and saved and sorted to database.
# 2024-09-12 09:47:22.448547: News data fetched and saved and sorted to database.
# 2024-09-12 09:48:22.647182: News data fetched and saved and sorted to database.
# 2024-09-12 09:49:22.825491: News data fetched and saved and sorted to database.
# 2024-09-12 09:50:23.127850: News data fetched and saved and sorted to database.
# 2024-09-12 09:51:23.238417: News data fetched and saved and sorted to database.
# 2024-09-12 09:52:23.432517: News data fetched and saved and sorted to database.
# 2024-09-12 09:53:23.538560: News data fetched and saved and sorted to database.
# 2024-09-12 09:54:23.760177: News data fetched and saved and sorted to database.
# 2024-09-12 09:55:23.944930: News data fetched and saved and sorted to database.
# 2024-09-12 09:56:24.041112: News data fetched and saved and sorted to database.
# 2024-09-12 09:57:24.271619: News data fetched and saved and sorted to database.
# 2024-09-12 09:58:24.473368: News data fetched and saved and sorted to database.
# 2024-09-12 09:59:24.655999: News data fetched and saved and sorted to database.
# 2024-09-12 10:00:24.753884: News data fetched and saved and sorted to database.
# 2024-09-12 10:01:24.940904: News data fetched and saved and sorted to database.
# 2024-09-12 10:02:25.041275: News data fetched and saved and sorted to database.
# 2024-09-12 10:03:25.216615: News data fetched and saved and sorted to database.
#
# Program terminated by user.
# Exiting program...

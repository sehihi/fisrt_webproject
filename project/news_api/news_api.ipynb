# %%
#### NAVER API

import requests
import mysql.connector
import time
from datetime import datetime

# 네이버 API 설정
NAVER_CLIENT_ID = 'c1M21TFbnPsLTH9OSif4'
NAVER_CLIENT_SECRET = 'futUGBEK8j'
NAVER_API_URL = 'https://openapi.naver.com/v1/search/news.json'

# MySQL 설정
MYSQL_HOST = 'localhost'
MYSQL_USER = 'root'
MYSQL_PASSWORD = '0000'
MYSQL_DATABASE = 'news_database'

# 특정 키워드 설정
KEYWORD = '삼성중공업'

def fetch_news_from_naver(keyword):
    # 헤더는 요청을 보낼 때 서버에 추가적인 정보를 전달하는 데 사용됩니다
    headers = {
        'X-Naver-Client-Id': NAVER_CLIENT_ID,
        'X-Naver-Client-Secret': NAVER_CLIENT_SECRET
    }
    # params는 URL에 추가될 쿼리 문자열을 포함하고 있으며, API에 전달할 검색 조건이나 옵션 등을 지정할 수 있습니다
    params = {
        'query': keyword,
        'display': 100,  # 최대 100개 뉴스 추출
        'start': 1,      # 시작 위치
        'sort': 'date'   # 날짜 기준으로 정렬
    }
    # requests.get 함수는 네이버 뉴스 API와 같은 웹 API에 요청을 보내고 응답을 받아옵니다
    response = requests.get(NAVER_API_URL, headers = headers, params = params)
    # response.raise_for_status()는 Python의 requests 라이브러리에서 사용되는 메서드로, HTTP 요청의 응답 상태 코드를 확인하고, 요청이 실패했을 경우 예외를 발생
    response.raise_for_status()
    return response.json()

def save_news_to_db(news_items):
    connection = mysql.connector.connect(
        host = MYSQL_HOST,
        user = MYSQL_USER,
        password = MYSQL_PASSWORD,
        database = MYSQL_DATABASE
    )
    cursor = connection.cursor()
    
    insert_query = """INSERT INTO news (title, description, link, pubDate) VALUES (%s, %s, %s, %s)"""
    check_query = """SELECT COUNT(*) FROM news WHERE link = %s"""


    
    # 네이버 API에서 받은 뉴스 기사 데이터베이스에 삽입
    for item in news_items:
        title = item['title'].replace('<b>', '').replace('</b>', '')  
        description = item['description'].replace('<b>', '').replace('</b>', '')
        link = item['link']
        pubDate = datetime.strptime(item['pubDate'], "%a, %d %b %Y %H:%M:%S %z")

        cursor.execute(check_query, (link,))
        count_result = cursor.fetchone()
        count = count_result[0] if count_result else 0

        if count == 0:
            document = (title, description, link, pubDate)
            cursor.execute(insert_query, document)
    
    connection.commit()
    cursor.close()
    connection.close()

def fetch_and_sort_news():
    connection = mysql.connector.connect(
        host = MYSQL_HOST,
        user = MYSQL_USER,
        password = MYSQL_PASSWORD,
        database = MYSQL_DATABASE
    )
    cursor = connection.cursor()
    
    # 뉴스 데이터를 pubDate 기준으로 정렬
    select_query = """SELECT title, description, link, pubDate FROM news ORDER BY pubDate DESC"""
    
    try:
        cursor.execute(select_query)
        news_items = cursor.fetchall()

    except mysql.connector.Error as err:
        print(f"Error: {err}")
    
    finally:
        cursor.close()
        connection.close()

    cursor.close()
    connection.close()

def main():
    try:
        while True:
            try:
                news_data = fetch_news_from_naver(KEYWORD)
                news_items = news_data.get('items', [])
                save_news_to_db(news_items)
                fetch_and_sort_news()
                print(f"{datetime.now()}: News data fetched and saved and sorted to database.")

            except Exception as e:
                print(f"Error during fetching or saving news: {e}")
            time.sleep(60)  # 1분 대기
    except KeyboardInterrupt:
        print("\nProgram terminated by user.")
    finally:
        print("Exiting program...")

if __name__ == "__main__":
    main()
# Out:
# 2024-09-10 16:04:37.961180: News data fetched and saved and sorted to database.
# 2024-09-10 16:05:38.179025: News data fetched and saved and sorted to database.
# 2024-09-10 16:06:38.383080: News data fetched and saved and sorted to database.
# 2024-09-10 16:07:38.484136: News data fetched and saved and sorted to database.
# 2024-09-10 16:08:38.792212: News data fetched and saved and sorted to database.
# 2024-09-10 16:09:38.968423: News data fetched and saved and sorted to database.
# 2024-09-10 16:10:39.152471: News data fetched and saved and sorted to database.
# 2024-09-10 16:11:39.349425: News data fetched and saved and sorted to database.
# 2024-09-10 16:12:39.532896: News data fetched and saved and sorted to database.
# 2024-09-10 16:13:39.644861: News data fetched and saved and sorted to database.
# 2024-09-10 16:14:39.929812: News data fetched and saved and sorted to database.
# 2024-09-10 16:15:40.110115: News data fetched and saved and sorted to database.
# 2024-09-10 16:16:40.282985: News data fetched and saved and sorted to database.
# 2024-09-10 16:17:40.469586: News data fetched and saved and sorted to database.
# 2024-09-10 16:18:40.686361: News data fetched and saved and sorted to database.
# 2024-09-10 16:19:40.890234: News data fetched and saved and sorted to database.
# 2024-09-10 16:20:41.110940: News data fetched and saved and sorted to database.
# 2024-09-10 16:21:41.207731: News data fetched and saved and sorted to database.
# 2024-09-10 16:22:41.406567: News data fetched and saved and sorted to database.
# 2024-09-10 16:23:41.506255: News data fetched and saved and sorted to database.
# 2024-09-10 16:24:41.702308: News data fetched and saved and sorted to database.
# 2024-09-10 16:25:41.905346: News data fetched and saved and sorted to database.
# 2024-09-10 16:26:42.098855: News data fetched and saved and sorted to database.
# 2024-09-10 16:27:42.296915: News data fetched and saved and sorted to database.
# 2024-09-10 16:28:42.512958: News data fetched and saved and sorted to database.
# 2024-09-10 16:29:42.716380: News data fetched and saved and sorted to database.
# 2024-09-10 16:30:42.910206: News data fetched and saved and sorted to database.
# 2024-09-10 16:31:43.042043: News data fetched and saved and sorted to database.
# 2024-09-10 16:32:43.278691: News data fetched and saved and sorted to database.
# 2024-09-10 16:33:43.488168: News data fetched and saved and sorted to database.
# 2024-09-10 16:34:43.604567: News data fetched and saved and sorted to database.
# 2024-09-10 16:35:43.826104: News data fetched and saved and sorted to database.
# 2024-09-10 16:36:43.960850: News data fetched and saved and sorted to database.
# 2024-09-10 16:37:44.220550: News data fetched and saved and sorted to database.
# 2024-09-10 16:38:44.434436: News data fetched and saved and sorted to database.
# 2024-09-10 16:39:44.639157: News data fetched and saved and sorted to database.
# 2024-09-10 16:40:44.848435: News data fetched and saved and sorted to database.
# 2024-09-10 16:41:45.041637: News data fetched and saved and sorted to database.
# 2024-09-10 16:42:45.264927: News data fetched and saved and sorted to database.
# 2024-09-10 16:43:45.377325: News data fetched and saved and sorted to database.
# 2024-09-10 16:44:45.601425: News data fetched and saved and sorted to database.
# 2024-09-10 16:45:45.822818: News data fetched and saved and sorted to database.
# 2024-09-10 16:46:46.064615: News data fetched and saved and sorted to database.
# 2024-09-10 16:47:46.263376: News data fetched and saved and sorted to database.
# 2024-09-10 16:48:46.463042: News data fetched and saved and sorted to database.
# 2024-09-10 16:49:46.662365: News data fetched and saved and sorted to database.
# 2024-09-10 16:50:46.895450: News data fetched and saved and sorted to database.
# 2024-09-10 16:51:47.000823: News data fetched and saved and sorted to database.
# 2024-09-10 16:52:47.243583: News data fetched and saved and sorted to database.
# 2024-09-10 16:53:47.439202: News data fetched and saved and sorted to database.
# 2024-09-10 16:54:47.650873: News data fetched and saved and sorted to database.
# 2024-09-10 16:55:47.890601: News data fetched and saved and sorted to database.
# 2024-09-10 16:56:48.097796: News data fetched and saved and sorted to database.
# 2024-09-10 16:57:48.223502: News data fetched and saved and sorted to database.
# 2024-09-10 16:58:48.417925: News data fetched and saved and sorted to database.
# 2024-09-10 16:59:48.645535: News data fetched and saved and sorted to database.
# 2024-09-10 17:00:48.825886: News data fetched and saved and sorted to database.
# 2024-09-10 17:01:48.926418: News data fetched and saved and sorted to database.
# 2024-09-10 17:02:49.262052: News data fetched and saved and sorted to database.
# 2024-09-10 17:03:49.447983: News data fetched and saved and sorted to database.
# 2024-09-10 17:04:49.636621: News data fetched and saved and sorted to database.
# 2024-09-10 17:05:49.845088: News data fetched and saved and sorted to database.
# 2024-09-10 17:06:50.016900: News data fetched and saved and sorted to database.
# 2024-09-10 17:07:50.221816: News data fetched and saved and sorted to database.
# 2024-09-10 17:08:50.561243: News data fetched and saved and sorted to database.
# 2024-09-10 17:09:50.761376: News data fetched and saved and sorted to database.
#
# Program terminated by user.
# Exiting program...
